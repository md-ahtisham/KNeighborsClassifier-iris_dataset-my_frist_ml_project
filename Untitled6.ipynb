# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
data = pd.read_csv("datairis.csv")
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Make sure to select the correct columns by their names
feature_columns = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
X = data[feature_columns]

# Initialize the scaler
scaler = StandardScaler()

# Fit and transform the data
scaled_features = scaler.fit_transform(X)

# Convert scaled features back to a DataFrame
scaled_df = pd.DataFrame(scaled_features, columns=feature_columns)

# %%
scaled_df =pd.DataFrame(scaled_features , columns=['SepalLengthCm',	'SepalWidthCm',	'PetalLengthCm',	'PetalWidthCm'])
scaled_df.head()
le = LabelEncoder()
data['Species'] = le.fit_transform(data['Species'])

processed_data= pd.concat([scaled_df, data['Species']], axis=1)
processed_data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      -0.900681      1.032057      -1.341272     -1.312977        0
# 1      -1.143017     -0.124958      -1.341272     -1.312977        0
# 2      -1.385353      0.337848      -1.398138     -1.312977        0
# 3      -1.506521      0.106445      -1.284407     -1.312977        0
# 4      -1.021849      1.263460      -1.341272     -1.312977        0

# %%
X= data[['SepalLengthCm',	'SepalWidthCm',	'PetalLengthCm',	'PetalWidthCm']]
y= data[['Species']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)  # 0.25 * 0.8 = 0.2 of the total data

# %%
k_values= range(1,30)
#K_value is hyperparmenter
validation_scores = []
#validation_scores is empty set that store the acc for each k

# %%
#for each value of k , we train KNN model on  the training set
#and evaluate the traing set acc on validation set
for k in k_values:
  knn= KNeighborsClassifier(n_neighbors=k)
  knn.fit(X_train, y_train)
  y_validation_predict =knn.predict(X_val)
  validation_scores.append(accuracy_score(y_val ,y_validation_predict))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:233: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:233: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:233: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
for k in k_values:
  knn= KNeighborsClassifier(n_neifhbors=k)
  knn.fit(X_train, y_train)
  y_validation_pred=knn.predict(x_val)
  validation_scores.append(accuracy_score(y_validation_predict,y_val))

# %%
optimal_k= k_values[validation_scores.index(max(validation_scores))]
print("Optimal K value:", optimal_k)
# best hyperperameter that give the  highest acc on  validation scoree store as optiml_k
# Out:
# Optimal K value: 5

# %% [markdown]
# train the final model on optimal_k with combind data set
#  of traing and validation set

# %%
final_knn = KNeighborsClassifier(n_neighbors=optimal_k)
final_knn.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:233: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %% [markdown]
# evaluate the final model
#  on test set

# %%
Y_test_predict = final_knn.predict(X_test)
test_accuracy= accuracy_score(Y_test_predict, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# Test Accuracy: 1.0
